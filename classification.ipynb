# %%
import pandas as pd
import numpy as np
import matplotlib as lb
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Admission_Predict.csv")

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (400, 9)

# %%
df.drop('Serial No.', axis=1, inplace=True)
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
from sklearn.preprocessing import Binarizer
bi = Binarizer(threshold=0.85)

df['Chance of Admit '] = bi.fit_transform(df[['Chance of Admit ']])

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                 1.0
# 1                 1.0
# ...

# %%
sb.barplot(data= df, x= df['Chance of Admit '] , y= df['CGPA'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='CGPA'>

# %%
sb.barplot(data= df, x= df['Chance of Admit '] , y= df['TOEFL Score'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='TOEFL Score'>

# %%
sb.lineplot(data= df, x= df['Chance of Admit '] , y= df['University Rating'])
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='University Rating'>

# %%
sb.scatterplot(data=df,x=df['GRE Score'],y=df['TOEFL Score'],hue=df['Chance of Admit '])
# Out:
# <Axes: xlabel='GRE Score', ylabel='TOEFL Score'>

# %%
x = df.drop('Chance of Admit ', axis = 1) #feature
y = df['Chance of Admit ']     #target

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
y.astype('int')
y
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 395    1.0
# 396    1.0
# 397    1.0
# 398    0.0
# 399    1.0
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
sb.barplot(data= df, x= df['University Rating'] , y= df['GRE Score'])
# Out:
# <Axes: xlabel='University Rating', ylabel='GRE Score'>

# %%
research = df['Research'].value_counts()
plt.pie(research,labels=research.index,autopct='%.2f')
plt.show()

# %%
sb.pairplot(df)

# %%
sb.scatterplot(data=df,x=df['GRE Score'],y=df['TOEFL Score'],hue=df['Chance of Admit '])
# Out:
# <Axes: xlabel='GRE Score', ylabel='TOEFL Score'>

# %% [markdown]
# # Cross-validation

# %%
len(x), len(y)
# Out:
# (400, 400)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0, test_size=0.2)

# %%
len(x_train), len(x_test)
# Out:
# (320, 80)

# %%
x_train.shape
# Out:
# (320, 7)

# %%
x_test.shape
# Out:
# (80, 7)

# %%
x_test
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 132        309          105                  5  3.5   3.5  8.56         0
# 309        308          110                  4  3.5   3.0  8.60         0
# 341        326          110                  3  3.5   3.5  8.76         1
# 196        306          105                  2  3.0   2.5  8.26         0
# 246        316          105                  3  3.0   3.5  8.73         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 14         311          104                  3  3.5   2.0  8.20         1
# 363        306          103                  2  2.5   3.0  8.36         0
# 304        313          106                  2  2.5   2.0  8.43         0
# 361        334          116                  4  4.0   3.5  9.54         1
# 329        297           96                  2  2.5   1.5  7.89         0
#
# [80 rows x 7 columns]

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 336        319          110                  3  3.0   2.5  8.79         0
# 64         325          111                  3  3.0   3.5  8.70         0
# 55         320          103                  3  3.0   3.0  7.70         0
# 106        329          111                  4  4.5   4.5  9.18         1
# 300        309          106                  2  2.5   2.5  8.00         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 323        305          102                  2  2.0   2.5  8.18         0
# 192        322          114                  5  4.5   4.0  8.94         1
# 117        290          104                  4  2.0   2.5  7.46         0
# 47         339          119                  5  4.5   4.0  9.70         0
# 172        322          110                  4  4.0   5.0  9.13         1
#
# [320 rows x 7 columns]

# %%
y_test
# Out:
# 132    0.0
# 309    0.0
# 341    1.0
# 196    0.0
# 246    0.0
#       ...
# 14     0.0
# 363    0.0
# 304    0.0
# 361    1.0
# 329    0.0
# Name: Chance of Admit , Length: 80, dtype: float64

# %%
y_train
# Out:
# 336    0.0
# 64     0.0
# 55     0.0
# 106    1.0
# 300    0.0
#       ...
# 323    0.0
# 192    1.0
# 117    0.0
# 47     1.0
# 172    1.0
# Name: Chance of Admit , Length: 320, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(random_state=0)

# %%
 classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
result = pd. DataFrame({
    'actual':y_test,
    'predicted':y_pred

})

# %%
result
# Out:
#      actual  predicted
# 132     0.0        0.0
# 309     0.0        0.0
# 341     1.0        1.0
# 196     0.0        0.0
# 246     0.0        0.0
# ..      ...        ...
# 14      0.0        0.0
# 363     0.0        0.0
# 304     0.0        0.0
# 361     1.0        1.0
# 329     0.0        0.0
#
# [80 rows x 2 columns]

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score 
from sklearn.metrics import classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92        49
#          1.0       0.90      0.84      0.87        31
#
#     accuracy                           0.90        80
#    macro avg       0.90      0.89      0.89        80
# weighted avg       0.90      0.90      0.90        80

# %%
new = [[309,105,5,3.5,3.5,8.56,0]]

classifier.predict(new)[0]
# Out:
# C:\Users\shamb\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.0

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,25))
plot_tree(classifier, fontsize=8, filled=True, rounded=True, feature_names=x.columns, class_names=['NA', 'AD']);
